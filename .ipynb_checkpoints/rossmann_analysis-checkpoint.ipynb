# %% [markdown]
# # Rossmann Sales Analysis - Project 1

# %% [markdown]
# ### By team 11: Jaganath Sairam and William Senay

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import plotnine as pn

# %% [markdown]
# ## Data reading and initial cleansing

# %%
df_train = pd.read_csv('Data/train.csv')
df_store = pd.read_csv('Data/store.csv')
# Out:
# C:\Users\wills\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# Datasets found on Kaggle at https://www.kaggle.com/c/rossmann-store-sales

# %%
df_train.count()
# Out:
# Store            1017209
# DayOfWeek        1017209
# Date             1017209
# Sales            1017209
# Customers        1017209
# Open             1017209
# Promo            1017209
# StateHoliday     1017209
# SchoolHoliday    1017209
# dtype: int64

# %%
df_train.dtypes
# Out:
# Store             int64
# DayOfWeek         int64
# Date             object
# Sales             int64
# Customers         int64
# Open              int64
# Promo             int64
# StateHoliday     object
# SchoolHoliday     int64
# dtype: object

# %% [markdown]
# There are no missing rows in the train dataset and the datatypes look correct.

# %%
df_store.count()
# Out:
# Store                        1115
# StoreType                    1115
# Assortment                   1115
# CompetitionDistance          1112
# CompetitionOpenSinceMonth     761
# CompetitionOpenSinceYear      761
# Promo2                       1115
# Promo2SinceWeek               571
# Promo2SinceYear               571
# PromoInterval                 571
# dtype: int64

# %%
df_store.dtypes
# Out:
# Store                          int64
# StoreType                     object
# Assortment                    object
# CompetitionDistance          float64
# CompetitionOpenSinceMonth    float64
# CompetitionOpenSinceYear     float64
# Promo2                         int64
# Promo2SinceWeek              float64
# Promo2SinceYear              float64
# PromoInterval                 object
# dtype: object

# %% [markdown]
# Now that the data is clean, let's look at the first five rows of the data:

# %%
df_train.head()
# Out:
#    Store  DayOfWeek        Date  Sales  Customers  Open  Promo StateHoliday  \
# 0      1          5  12/26/2014      0          0     0      0            c
# 1      2          5  12/26/2014      0          0     0      0            c
# 2      3          5  12/26/2014      0          0     0      0            c
# 3      4          5  12/26/2014      0          0     0      0            c
# 4      5          5  12/26/2014      0          0     0      0            c
#
#    SchoolHoliday
# 0              1
# 1              1
# 2              1
# 3              1
# 4              1

# %%
df_store.head()
# Out:
#    Store StoreType Assortment  CompetitionDistance  CompetitionOpenSinceMonth  \
# 0      1         c          a               1270.0                        9.0
# 1      2         a          a                570.0                       11.0
# 2      3         a          a              14130.0                       12.0
# 3      4         c          c                620.0                        9.0
# 4      5         a          a              29910.0                        4.0
#
#    CompetitionOpenSinceYear  Promo2  Promo2SinceWeek  Promo2SinceYear  \
# 0                    2008.0       0              NaN              NaN
# 1                    2007.0       1             13.0           2010.0
# 2                    2006.0       1             14.0           2011.0
# 3                    2009.0       0              NaN              NaN
# 4                    2015.0       0              NaN              NaN
#
#      PromoInterval
# 0              NaN
# 1  Jan,Apr,Jul,Oct
# 2  Jan,Apr,Jul,Oct
# 3              NaN
# 4              NaN

# %%
df = pd.merge(df_train, df_store, on='Store')
df.head()
# Out:
#    Store  DayOfWeek        Date  Sales  Customers  Open  Promo StateHoliday  \
# 0      1          5  12/26/2014      0          0     0      0            c
# 1      1          4  12/25/2014      0          0     0      0            c
# 2      1          4  12/26/2013      0          0     0      0            c
# 3      1          3  12/25/2013      0          0     0      0            c
# 4      1          1    4/6/2015      0          0     0      0            b
#
#    SchoolHoliday StoreType Assortment  CompetitionDistance  \
# 0              1         c          a               1270.0
# 1              1         c          a               1270.0
# 2              1         c          a               1270.0
# 3              1         c          a               1270.0
# 4              1         c          a               1270.0
#
#    CompetitionOpenSinceMonth  CompetitionOpenSinceYear  Promo2  \
# 0                        9.0                    2008.0       0
# 1                        9.0                    2008.0       0
# 2                        9.0                    2008.0       0
# 3                        9.0                    2008.0       0
# 4                        9.0                    2008.0       0
#
#    Promo2SinceWeek  Promo2SinceYear PromoInterval
# 0              NaN              NaN           NaN
# 1              NaN              NaN           NaN
# 2              NaN              NaN           NaN
# 3              NaN              NaN           NaN
# 4              NaN              NaN           NaN

# %%
df.shape
# Out:
# (1017209, 18)

# %%
df.count()
# Out:
# Store                        1017209
# DayOfWeek                    1017209
# Date                         1017209
# Sales                        1017209
# Customers                    1017209
# Open                         1017209
# Promo                        1017209
# StateHoliday                 1017209
# SchoolHoliday                1017209
# StoreType                    1017209
# Assortment                   1017209
# CompetitionDistance          1014567
# CompetitionOpenSinceMonth     693861
# CompetitionOpenSinceYear      693861
# Promo2                       1017209
# Promo2SinceWeek               509178
# Promo2SinceYear               509178
# PromoInterval                 509178
# dtype: int64

# %% [markdown]
# This concludes the cleaning section. We now have ready to use for analysis datasets.

# %% [markdown]
# ## Initial Exploration: Finding Relationships and Points of Interest

# %%
school_holiday_chart = sns.FacetGrid(df, col="SchoolHoliday", margin_titles=True)
school_holiday_chart.map(plt.scatter, "Customers", "Sales", edgecolor="w").add_legend()

# %%
state_holiday_chart = sns.FacetGrid(df, col="StateHoliday", margin_titles=True)
state_holiday_chart.map(plt.scatter, "Customers", "Sales", edgecolor="w").add_legend()

# %%
day_of_week_chart = sns.FacetGrid(df, col='DayOfWeek', hue='Promo')
day_of_week_chart.map(plt.scatter, 'Customers', 'Sales', edgecolor='w')

# %%
pn.ggplot(pn.aes(x='DayOfWeek', y='Sales'), df_train) + pn.geom_jitter(alpha=0.05)
# Out:
# <ggplot: (172201698091)>

# %%
df_train_example = df_train[:100000]

# %%
df_train_example["DayOfWeekCat"] = df_train_example.apply(lambda x: str(x.DayOfWeek), axis=1)
# Out:
# C:\Users\wills\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df_train_example.DayOfWeekCat.value_counts()
# Out:
# 4    20618
# 5    17111
# 1    17034
# 3    13530
# 2    11458
# 7    10344
# 6     9905
# Name: DayOfWeekCat, dtype: int64

# %%
pn.ggplot(pn.aes(x='DayOfWeekCat', y='Sales'), df_train_example) + pn.geom_jitter(pn.aes(color="DayOfWeekCat"), alpha=0.6)
# Out:
# <ggplot: (-9223371864572247864)>
